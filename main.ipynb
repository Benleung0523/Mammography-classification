# %%
import pandas as pd
import re
import os

# %%
haha = pd.read_csv("calc_case_description_train_set.csv")

# %%
def Changepath(str):
    str = re.sub(r'\/', '\\\\', str)
    return str

# %%
haha
# Out:
#      patient_id  breast density left or right breast image view  \
# 0       P_00005               3                RIGHT         CC
# 1       P_00005               3                RIGHT        MLO
# 2       P_00007               4                 LEFT         CC
# 3       P_00007               4                 LEFT        MLO
# 4       P_00008               1                 LEFT         CC
# ...         ...             ...                  ...        ...
# 1541    P_02566               2                RIGHT        MLO
# 1542    P_02572               2                 LEFT         CC
# 1543    P_02572               2                 LEFT        MLO
# 1544    P_02584               1                 LEFT         CC
# 1545    P_02584               1                 LEFT        MLO
#
#       abnormality id abnormality type              calc type  \
# 0                  1    calcification              AMORPHOUS
# 1                  1    calcification              AMORPHOUS
# ...

# %%
haha["image file path"] = haha["image file path"].apply(Changepath)

# %%
filtered_haha["image file path"][1]
# Out:
# 'Calc-Training_P_00005_RIGHT_MLO\\1.3.6.1.4.1.9590.100.1.2.427517897311902339923511678883689433338\\1.3.6.1.4.1.9590.100.1.2.250596608311207922527805669693579696727\\'

# %%
haha["new_name"] = haha['index'].astype(str) + haha["pathology"]

# %%
haha['index'] = haha.index

# %%
haha
# Out:
#      patient_id  breast density left or right breast image view  \
# 0       P_00005               3                RIGHT         CC
# 1       P_00005               3                RIGHT        MLO
# 2       P_00007               4                 LEFT         CC
# 3       P_00007               4                 LEFT        MLO
# 4       P_00008               1                 LEFT         CC
# ...         ...             ...                  ...        ...
# 1541    P_02566               2                RIGHT        MLO
# 1542    P_02572               2                 LEFT         CC
# 1543    P_02572               2                 LEFT        MLO
# 1544    P_02584               1                 LEFT         CC
# 1545    P_02584               1                 LEFT        MLO
#
#       abnormality id abnormality type              calc type  \
# 0                  1    calcification              AMORPHOUS
# 1                  1    calcification              AMORPHOUS
# ...

# %%
value_list = ["MALIGNANT","BENIGN"]
boolean_series = haha["pathology"].isin(value_list)
filtered_haha = haha[boolean_series]

# %%
filtered_haha.columns = filtered_haha.columns.str.replace(' ', '_')

# %%
filtered_haha
# Out:
#      patient_id  breast density left or right breast image view  \
# 0       P_00005               3                RIGHT         CC
# 1       P_00005               3                RIGHT        MLO
# 2       P_00007               4                 LEFT         CC
# 3       P_00007               4                 LEFT        MLO
# 22      P_00011               3                 LEFT         CC
# ...         ...             ...                  ...        ...
# 1541    P_02566               2                RIGHT        MLO
# 1542    P_02572               2                 LEFT         CC
# 1543    P_02572               2                 LEFT        MLO
# 1544    P_02584               1                 LEFT         CC
# 1545    P_02584               1                 LEFT        MLO
#
#       abnormality id abnormality type              calc type  \
# 0                  1    calcification              AMORPHOUS
# 1                  1    calcification              AMORPHOUS
# ...

# %%
og_name = "C:\\Users\\Ben\\Desktop\\646data\\CBIS-DDSM\\"+filtered_haha.image_file_path+"1-1.png"
destination = "C:\\Users\\Ben\\Desktop\\646data\\CBIS-DDSM\\"+filtered_haha.image_file_path+filtered_haha.new_name+".png"
# Out:
# 'C:\\Users\\Ben\\Desktop\\646data\\CBIS-DDSM\\Calc-Training_P_00005_RIGHT_CC\\1.3.6.1.4.1.9590.100.1.2.408909860712120272633130274602115723157\\1.3.6.1.4.1.9590.100.1.2.47414316010368386519740343172775938548\\1-1.png'

# %%
from pathlib import Path

# %%
print(Path.cwd())
# Out:
# C:\Users\Ben\Desktop

# %%
m_path= "C:\\Users\\Ben\\Desktop\\646data\\CBIS-DDSM\\MALIGNANT\\"+filtered_haha.new_name+".png"
b_path= "C:\\Users\\Ben\\Desktop\\646data\\CBIS-DDSM\\BENIGN\\"+filtered_haha.new_name+".png"

m_path[i]
# Out:
# 'C:\\Users\\Ben\\Desktop\\646data\\CBIS-DDSM\\MALIGNANT\\1544BENIGN.png'

# %%
for i in range(0,1545):
    try:

    if filtered_haha.pathology[i] == "MALIGNANT":
         os.rename(destination[i],m_path[i])

    else:
        
            os.rename(destination[i],b_path[i])
        except Exception:
            pass
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-52fe46449a53> in <module>
#       1 for i in range(0,1545):
#       2
# ----> 3     if filtered_haha.pathology[i] == "MALIGNANT":
#       4
#       5         try:
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4402         k = self._convert_scalar_indexer(k, kind="getitem")
#    4403         try:
# -> 4404             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4405         except KeyError as e1:
# ...

# %%
os.rename("C:\Users\Ben\Desktop\646data\CBIS-DDSM\Calc-Training_P_00005_RIGHT_CC\1.3.6.1.4.1.9590.100.1.2.408909860712120272633130274602115723157\1.3.6.1.4.1.9590.100.1.2.47414316010368386519740343172775938548\\1-1.png","C:\\Users\\Ben\\Desktop\\646data\\CBIS-DDSM\\Calc-Training_P_00005_RIGHT_CC\\1.3.6.1.4.1.9590.100.1.2.408909860712120272633130274602115723157\\1.3.6.1.4.1.9590.100.1.2.47414316010368386519740343172775938548\\123.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-92-a20b1a4e2faf> in <module>
# ----> 1 os.rename("C:\\Users\\Ben\\Desktop\\646data\\CBIS-DDSM\\Calc-Training_P_00005_RIGHT_CC\\1.3.6.1.4.1.9590.100.1.2.408909860712120272633130274602115723157\\1.3.6.1.4.1.9590.100.1.2.47414316010368386519740343172775938548\\1-1.png","C:\\Users\\Ben\\Desktop\\646data\\CBIS-DDSM\\Calc-Training_P_00005_RIGHT_CC\\1.3.6.1.4.1.9590.100.1.2.408909860712120272633130274602115723157\\1.3.6.1.4.1.9590.100.1.2.47414316010368386519740343172775938548\\123.png")
#
# ...

# %%
og_name[22]
# Out:
# 'C:\\Users\\Ben\\Desktop\\646data\\CBIS-DDSM\\Calc-Training_P_00011_LEFT_CC\\1.3.6.1.4.1.9590.100.1.2.276155542712021701434787721271107268211\\1.3.6.1.4.1.9590.100.1.2.389208391412680785736990872734216560014\\1-1.png'

# %%
try:
    do_something()
except Exception:
    pass
